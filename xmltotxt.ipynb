# %% [markdown]
# <a href="https://colab.research.google.com/github/Mandloi1/projectwork/blob/master/xmltotxt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# Clone the repository of XmlToTxt convertor
# !git clone https://github.com/Isabek/XmlToTxt.git
# Out:
# Cloning into 'XmlToTxt'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 99 (delta 19), reused 16 (delta 16), pack-reused 76
# Unpacking objects: 100% (99/99), done.

# %%
pwd
# Out:
# '/content/drive/My Drive'

# %%
# Enter to the directory XmlToTxt
# %cd XmlToTxt/
# Out:
# /content/drive/My Drive/XmlToTxt

# %%
# Install the requirements of XmlToTxt convertor
# !pip install declxml==0.9.1

# %%
# Clean the Input & Output directories
# !rm -rf xml/*.*
# !rm -rf out/*.*

# %%
pwd
# Out:
# '/content/drive/MyDrive/XmlToTxt'

# %%
# Copy the XML files to be converted to text mode
# !cp -r /content/drive/MyDrive/ANNOTATIONS/*.xml /content/drive/MyDrive/XmlToTxt/xml

# %%
# All the XML files listed below
# !ls /content/drive/MyDrive/XmlToTxt/xml
# Out:
# ANNOTATIONS	   patches_100.xml	    rolled-in_scale_101.xml
# crazing_100.xml    patches_101.xml	    rolled-in_scale_102.xml
# crazing_101.xml    patches_102.xml	    rolled-in_scale_103.xml
# crazing_102.xml    patches_103.xml	    rolled-in_scale_104.xml
# crazing_103.xml    patches_104.xml	    rolled-in_scale_105.xml
# crazing_104.xml    patches_105.xml	    rolled-in_scale_106.xml
# crazing_105.xml    patches_106.xml	    rolled-in_scale_107.xml
# crazing_106.xml    patches_107.xml	    rolled-in_scale_108.xml
# crazing_107.xml    patches_108.xml	    rolled-in_scale_109.xml
# crazing_108.xml    patches_109.xml	    rolled-in_scale_10.xml
# crazing_109.xml    patches_10.xml	    rolled-in_scale_110.xml
# crazing_10.xml	   patches_110.xml	    rolled-in_scale_111.xml
# crazing_110.xml    patches_111.xml	    rolled-in_scale_112.xml
# crazing_111.xml    patches_112.xml	    rolled-in_scale_113.xml
# crazing_112.xml    patches_113.xml	    rolled-in_scale_114.xml
# ...

# %%
# Modify the classes.txt files 
# !cat classes.txt
# Out:
# crazing
# inclusion
# patches
# pitted_surface
# rolled-in_scale
# scratches

# %%
# !sed -i 's/bus/crazing/' classes.txt
# !sed -i 's/minivan/inclusion/' classes.txt
# !sed -i 's/auto/patches/' classes.txt
# !sed -i 's/truck/pitted_surface/' classes.txt
# !sed -i 's/minibus/rolled-in_scale/' classes.txt
# !sed -i 's/가각/scratches/' classes.txt


# !cat classes.txt
# Out:
# crazing
# inclusion
# patches
# pitted_surface
# minicrazing
# scratches

# %%
# !sed -i 's/minicrazing/rolled-in_scale/' classes.txt

# !cat classes.txt
# Out:
# crazing
# inclusion
# patches
# pitted_surface
# rolled-in_scale
# scratches

# %%
pwd
# Out:
# '/content/drive/My Drive/XmlToTxt'

# %%
# !python xmltotxt.py -xml xml -out out
# Out:
# Please, add 'minibus' to classes.txt file.

# %%
# One of the sample input XMl file
# !cat /content/drive/MyDrive/ANNOTATIONS/crazing_104.xml
# Out:
# <annotation>
# 	<folder>cr</folder>
# 	<filename>crazing_104.jpg</filename>
# 	<source>
# 		<database>NEU-DET</database>
# 	</source>
# 	<size>
# 		<width>200</width>
# 		<height>200</height>
# 		<depth>1</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>crazing</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>4</xmin>
# 			<ymin>4</ymin>
# 			<xmax>110</xmax>
# 			<ymax>136</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>crazing</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>142</xmin>
# 			<ymin>10</ymin>
# 			<xmax>197</xmax>
# 			<ymax>56</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		<name>crazing</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>137</xmin>
# 			<ymin>42</ymin>
# 			<xmax>199</xmax>
# 			<ymax>116</ymax>
# 		</bndbox>
# ...

# %%
# Output text files of the same XML file above.
# !cat /content/drive/MyDrive/XmlToTxt/out/crazing_104.txt
# Out:
# 0 0.285000 0.350000 0.530000 0.660000
# 0 0.847500 0.165000 0.275000 0.230000
# 0 0.840000 0.395000 0.310000 0.370000
# 2 0.490000 0.922500 0.200000 0.155000

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15050, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15050 (delta 16), reused 34 (delta 14), pack-reused 15002
# Receiving objects: 100% (15050/15050), 13.45 MiB | 19.42 MiB/s, done.
# Resolving deltas: 100% (10214/10214), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/XmlToTxt/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2021-05-23 11:43:28--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  20.7MB/s    in 12s
#
# 2021-05-23 11:43:41 (19.3 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)
